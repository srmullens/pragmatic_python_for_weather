# %% [markdown]
# # Syntax Problem #2
#
# ## Objectives
# 1.	Practice writing and running Python code and using comments.
# 3.	Use Python I/O.
# 4.	Use standard mathematical operations.
#
# ## Problem
# 1. Write a Python program to calculate the time (in seconds) to move a certain distance (in miles) travelling at a given speed (in miles per hour). Print the time in seconds.
# * Use the input() function to capture the distance and speed from the user. Be sure to prompt for correct units.
# * Have the output say what the input distance and speed is along with the final calculated time to travel the distance that was input. Print the basic information.
# * Print the same information in a complete sentence using f-strings.
#
# ## Notes:
# * Recall that distance = speed * time.
# * Feel free to use a previous script to start a new problem, especially if it has code that will be useful to have in a new program.
# * Make sure appropriate comments are present in your code.
# * Make output informative so that anyone running your program understands what is being written without seeing the assignment.
# * Name the program `syntax2_<username>.ipynb`. Download the file and upload it to Canvas.
