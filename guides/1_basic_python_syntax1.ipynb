# %% [markdown]
# # Introduction to Python

# %% [markdown]
# ## Welcome to Python!
#
# * Python is a read language
#     - NOT compiled! Fortran, C, and Java are examples of compiled languages. These can run faster, which mostly matters with large datasets.
#     - The typed psuedo-code that you write is interpreted and run directly at runtime. This is more intuitive for us to write and read compared to other languages.
# * Object Oriented
#     - Object-oriented programming (OOP) is a programming paradigm based on the concept of "objects", which are data structures that contain data, in the form of fields, often known as attributes; and code, in the form of procedures, often known as methods. - Defn. from Wikipedia
#     - We think of variables, but these are more generally "objects" that contain data, attributes, and code that we can use in more general ways.
#     - We won't write objected oriented stuff, but we'll use it extensively!

# %% [markdown]
# ## Modular System
# * Base python is small.
# * Python has been around since 1991, and we are currently on Python 3.
# * Base python allows others to create lots of third-party modules to complete high-level tasks important to us.
#     - Within Earth System Science, popular modules include: numpy, scipy, matplotlib, cartopy, netcdf4, pandas, xarray, pyart, r2py, scikit-learn, metpy
#     - Need to import modules to use their methods with your data objects (this is that whole object-oriented programming bit!)
#     - You can think of modules as large groups of very useful functions or subprograms that we can bring into our code to address our problems.

# %% [markdown]
# ## Python Syntax
# * Indented Langauge
#     - To control the flow of the program, you must abide by different levels of indentation for any code to be interpreted correctly.
#     - The most common indentation amount is 4 spaces, but 2 spaces are sometimes used.
# * Community-based development
#     - modules are developed by people for free.
#     - There are organizations like Scientific Python Development via NumFocus (https://numfocus.org) who request support so their modules can remain free.
#     - Most modules use a common repository: GitHub. Can track issues and maintain code in this environment.

# %% [markdown]
# ## Python in this course
# If you install the same version on a personal computer with the same modules, your code *should* work on both.
#
# * Python 3.13.14 (via a conda-forge distribution)
#
# * You will also need the same modules we will use, including:
#     - numpy - Fast mathematical operations on ndarrays
#     - scipy - Mathematical algorithms and convenience functions built on NumPy
#     - pandas - Data analysis and manipulation tool; data frames; varying data formats
#     - geopandas - Support for geographic data on top of Pandas objects
#     - xarray - Labeled ndarrays for intuitive scientific computing
#     - seaborn - Statistical data visualization library
#     - matplotlib - Plotting and visualization in python
#     - cartopy - Produce maps and other geospatial data analyses
#     - plotly - Interactive visualizations
#     - metpy - NSF Unidata: read, visualize, and perform calculations on weather data
#     - netcdf4 - NSF Unidata: Python interface to the netCDF C library
#     - siphon - NSF Unidata: Python interface to NSF Unidata's THREDDS Data Server
#     - tropycal - get tropical cyclone datasets from HURDAT2
#     - shapely - make calculations based on shapes
#     - statistic - Calculate common statistics.
#     - statsmodels - Statistical models and statistical data exploration
#     - ipywidgets - Interactive Python widgets for Jupyter notebooks
#     - scikit-learn - Machine learning library in Python
#     - arm_pyart - Weather radar algorithms and utilities
#     - cfgrib - Map GRIB files to netCDF
#     - ppl_toolkits
#     - sklearn
#
#
# * Other popular modules include:
#     - argopy - data from autonomous Argo float buoys
#     - autumnplot-gl - hardware-accelerated geospatial data plotting in the browser
#     - cdsapi - climate data store api
#     - DRpy - GPM-DPR data. dual-frequency precipitation radar (DPR) on the global precipitation measurement (GPM) satellite.
#     - ecape - calculate Entrainment CAPE using metpy and numpy
#     - FireWxPy - fire weather
#     - pythreadex - retrieving and plotting ThreadEx station data
#     - QTrack - african easterly wave tracker
#     - satpy - meteorological remote sensing data
#     - SHARPpy - sounding and hodograph analysis and research program in python
#     - SOMpy - self organizing maps
#     - Sounderpy - access vertical profile data
#     - tcpyPI - tropical cyclone potential intensity

# %% [markdown]
# ## Variable Assignment
#
# REF: DeCaria Section 2.2
#
# * The most basic task in coding.
# * Variables can be many types: integer, float, string, list, tuple, dictionary, set, boolean, NoneType.
# * Unlike other languages, there is no need to declare variable types! Python will assume a type based on the value assigned to variable name.
#
# What is the variable? What is the object?

# %%
# Assumes type based on value given
# Type a string (characters, words)
name = 'Stephen'

# Type an integer
temp = 20

# %% [markdown]
# To save the data in the above cell, you need to run the cell. In Jupyter Notebook, we run each cell individually.
# * Shift + Enter
# * Play button at the top.
#
# We can also retrieve the data stored in each variable again.
# In the box below, type the name of one of your variables and run it to see it output.
#
# To see one of the attributes of the data, use the type() function. Create a new variable with a decimal to see a new type.

# %% [markdown]
# ### Reserved Words
#
# There are a number of words that you should not use to define a variable, becuase that words serves a very specific functionality within the Python language. The words to avoid are:
#
# | reserved | words | don't | use |
# | -- | -- | -- | -- |
# |`False`|`def`|`if`|`raise`|
# |`None`|`del`|`import`|`return`|
# |`True`|`elif`|`in`|`try`|
# |`and`|`else`|`is`|`while`|
# |`as`|`except`|`lambda`|`with`|
# |`assert`|`finally`|`nonlocal`|`yield`|
# |`break`|`for`|`not`||
# |`class`|`from`|`or`||
# |`continue`|`global`|`pass`||
#
# Jupyter Notebook knows these words. Type them below and note they change color. In a terminal window, you can customize these colors.

# %%
help('keywords')

# %% [markdown]
# ## Print Function
#
# In Jupyter Notebook, we can print the output of a variable simply by writing it in a code cell and running the cell. But that doesn't work if the cell contains more code than that, and doesn't work in a python script. In those cases, you will want to use the print() function.
#
# To print a variable, simply put the variable in the print statement.
#
# ```python
# print(name)
# ```
#
# Output:
# ```
# Kevin
# ```
#
# If you try to print the variable in a string, it won't work even though one of the words is a variable.
# ```python
# print('My name is name.')
# ```
#
# That's a good thing when you think about it. There are a few ways you can print a variable as part of a string. The oldest way is to have the print function print a list of things, namely the string and your variable.
#
# ```python
# print('My name is',name)
# ```
#
# To format the variable within the string, you can either use the modulo operator (%) or the format function.
#
# ```python
# print('My name is %s' % (name))
# print('My name is {0}'.format(name))
# ```

# %% [markdown]
# What happens when you capitalize the variable name?
# ```python
# print('My name is',Name)
# ```
# What happens when you use double quotes " instead of single quotes ' ?
# ```python
# print("My name is",name)
# print("My name is',name)
# print('My name is",name)
# ```

# %% [markdown]
# Those are all pretty much the same when using strings. If you are using numbers, these latter two ways allowed you to format numbers in your print statement. Compare the following:
#
# ```python
# slp = 1013.25
# temp = 293.15
# print('Standard temperature is',temp,'Kelvin.')
# print('Standard temperature is about %0.0f Kelvin.' % (temp))
# print('The environment was {1:.1f} Kelvin and {0:10.2f} hPa, standard temperature and pressure.'.format(slp,temp))
# ```

# %% [markdown]
# To make the print statements more readable, the 'f-string' was created to replace the format function. Place an f before the beginning of string statement and use curly brackets (e.g., {}) to call the variable you wish to print in the statement.
#
# ```python
# print(f'My name is {name}')
# print(f'Standard temperature is {temp} Kelvin.')
# print(f'Standard temperature is about {temp:0.0f} Kelvin.')
# print(f'The environment was {temp:.1f} Kelvin and {slp:10.2f} hPa, standard temperature and pressure.')
# ```

# %% [markdown]
# Notice the two big benefits of f-strings!
# First, including a variable in your string is much more readable. Here are other ways to print the above example:
# ```python
# print('My name is ' + name)
# print('My name is' + ' ' + name)
# print('My name is',name)
# print('My name is {}'.format(name))
# print('My name is %s'.format(name))
# ```
# These will look all right when printed, but the code itself is clunky and you have to remember how syntax relates to spaces.
#
# What if you have multiple variables to print?
# ```python
# name = 'Dave'
# age = 20
# gpa = 3.7
# print('My name is %s. My age is %d. My GPA is %d.' % (name,age,gpa))
# ```
# Here, the `%s` formats the variable as a string, `%d` formats the variable as an integer, `%f` is a float, `%g` is a generic number. So much to remember! And where the variables go in the line must be tracked down with your eyes. It's very unreadable. With f-strings, this is much more readable and would be much easier to troubleshoot an error:
# ```python
# print(f'My name is {name}. My age is {age}. My GPA is {gpa}.')
# ```
#
# Second, if your variable is a number, you can easily format the output right in the print statement. Here are some examples:

# %%
float_variable = 3.1415926

# This prints just the first 2 decimals (Note: the # symbol in python code makes this a comment.
print(f'First two decimals places only: {float_variable:.2f}')

# This prints a + or - to explicitly show the number is positive or negative.
print(f'\nShow the + or - sign: {float_variable:+}')

# This makes sure the number takes up 10 spaces and aligns the number to the right. The beginning space 
print(f'\nTen spaces, right aligned: ->{float_variable:>11}<-')

# This combines the lines above. The beginning underscore fills the spaces to the left of the number with underscores as needed. 
print(f'\nAll together: ->{float_variable:_>+11.2f}<-')

# This converts a number automatically to a percent, and demands two decimal places.
decimal = 0.378
print(f'\npercent: {decimal:.2%}')

# This converts a number to scientific notation, and demands three decimal places. Note that it rounds for you.
print(f'\nScientific notation: {float_variable:.3e}')
print(f'Scientific notation: {float_variable:.3E}')

# This only prints numbers in scientific notation if the exponent is greater than 4 or smaller than -4.
# Note that I have also demanded 7 spaces for the output and the numbers are right aligned.
print(f'\nOnly scientific for large or small numbers: {100000:>7.4g}')
print(f'Only scientific for large or small numbers: {10000:>7.4g}')
print(f'Only scientific for large or small numbers: {1000:>7.4g}')
print(f'Only scientific for large or small numbers: {100:>7.4g}')
print(f'Only scientific for large or small numbers: {10:>7.4g}')
print(f'Only scientific for large or small numbers: {1:>7.4g}')
print(f'Only scientific for large or small numbers: {0.1:>7.4g}')
print(f'Only scientific for large or small numbers: {0.01:>7.4g}')
print(f'Only scientific for large or small numbers: {0.001:>7.4g}')
print(f'Only scientific for large or small numbers: {0.0001:>7.4g}')
print(f'Only scientific for large or small numbers: {0.00001:>7.4g}')
print(f'Only scientific for large or small numbers: {0.000001:>7.4g}')
# Out:
# First two decimals places only: 3.14
#
# Show the + or - sign: +3.14159
#
# Ten spaces, right aligned: ->    3.14159<-
#
# All together: ->______+3.14<-
#
# percent: 37.80%
#
# Scientific notation: 3.142e+00
# Scientific notation: 3.142E+00
#
# Only scientific for large or small numbers:   1e+05
# Only scientific for large or small numbers:   1e+04
# Only scientific for large or small numbers:    1000
# Only scientific for large or small numbers:     100
# Only scientific for large or small numbers:      10
# Only scientific for large or small numbers:       1
# Only scientific for large or small numbers:     0.1
# Only scientific for large or small numbers:    0.01
# Only scientific for large or small numbers:   0.001
# Only scientific for large or small numbers:  0.0001
# Only scientific for large or small numbers:   1e-05
# Only scientific for large or small numbers:   1e-06

# %% [markdown]
# ## Code Comments
#
# It is imperative that you comment your code to ensure you remember what pieces of your code are doing. This will help when you come back to old code after a period of time or share your code with someone else. Comments can be made in two primary ways, through stand alone comments on one line or inline, either way you want to use the special character `#`, which is officially known as an octothorp or better known to you as a hashtag.
#
# Any line that starts with a `#` will not be executed at runtime. Any line that has a `#` in it, nothing will be executed after that symbol.
#
# ```python
# # This is a comment and won't be executed
# # The following line is executable code
# print('Hello') # this is an inline comment
# ```
#
# Output
# ```python
# Hello
# ```

# %%
# Setting a temperature value
tmpc = 28
print(f'The current temperature is {tmpc}C') # Printing out the current temperature

# %% [markdown]
# Write some code that tells the user your three most favorite places in your home state.
