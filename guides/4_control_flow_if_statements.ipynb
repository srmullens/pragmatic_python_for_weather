# %% [markdown]
# # Control Flow - If Statements
#
# So far we have learned computer programming that only works in a linear fashion. There will be times when we want to do things only when certain conditions are met. In order to facilitate this within a programming language we need a way for the program to know the "truthiness" of a statement.
#
# REF: DeCaria Section 5.3

# %% [markdown]
# ## Logical Operators
#
# In order test values, we need a set of operators that can help the computer determine the "truthiness". Here are the list of the most common logical operators used in Python.
#
# | symbol | meaning|
# | :-: | :-: |
# | < | less than |
# | <= | less than or equal |
# | > | greater than |
# | >= | greater than or equal |
# | == | equal to |
# | != | not equal to |
# | `and` | two things are true |
# | `or` | one of two things are true |
# | `not` | this is false |
#
# RESULT:
# The result of these comparisons is a binary `True` or `False` value. These are useful for the `if` statements below.
#
# Let's test out the operators.
#
# Change the inequality in this print statement.

# %%
# Test common logical operators
print(5 < 10)

# %% [markdown]
# Create a list that partially matches `yourlist`. Compare them using `and`, `or`, or `not`.

# %%
# Test and, or logical operators
mylist = []
yourlist = [0, 5, 10, 15, 20, 25]
print(mylist and yourlist)

# %% [markdown]
# Note: zero or empty objects are evaluated as `False`. All other values and non-empty objects are evaluated as `True`. We can test this using the boolean function `bool()`.
# ```python
# print(bool(0))
# print(bool(1))
# print(bool(3.14))
# print(bool([]))
# print(bool([0]))
# print(bool([1]))
# print(bool([0, 1, 2]))
# ```

# %% [markdown]
# The `and`, `or`, and `not` symbols evaluate the truthiness of the statements being compared in a non-bitwise manner. These are the statements you should use when making the vast majority of comparisons. Other programming languages will instead use the symbols `&&` for `and` and `||` for `or`. Python does not use these commands. But, there *are* commands `&` and `|` that do "and" and "or" commands to compare each bit of a number after it has been converted to 1s and 0s, not a number as we would read them.
#
# | symbol | meaning|
# | :-: | :-: |
# | \| | bitwise or |
# | & | bitwise and |
# | ~ | bitwise not |
#
# For more detail: https://www.geeksforgeeks.org/python-bitwise-operators/
#
# Again, more likely than not, it will be best to use the non-bitwise `and`, `or`, and `not` versions.

# %% [markdown]
# ## If, Else If, Else Statements
#
# At a minimum you must include a single `if` call, but can then include any number of `elif` statements to check other possibilities, and then a single concluding `else` statement can be used as a catch-all for the if statement (with no need to have any `elif`s to have an `else`). Here is a full example of using `if`, `elif`, and `else` in a single if statement.
#
# Notice that at the end of each line contain a part of the if construct there is a colon (`:`), that is the important character for the Python interpreter to know it has reached the end of the logical statment and it should be evaluted to determine its truithiness. Also note that the `else` statement does not contain any logical condition as it only gets executed if each test before it results in a `False` designation.
#
#
# ```python
# a = 5
# b = 10
#
# if a < b:
#     print(a)
# ```
# Output:
# ```
# 5
# ```
#
# **NOTE:** Here we see the importance of Python being an *indented* language. Everything within the `if` statment and any `elif` or `else` statments must be indented the same amount. The standard indent is four spaces long.
#
# Let's test some if statements...

# %% [markdown]
# ### if statment construct - stand alone
#
# Here is the construct of a simple if statment where you are looking to test a single conditional element (e.g., 5 < 10) to then choose to take a specific action (whatever is in the code block indented with the if statement) if it is `True`.
# ```python
# if condition:
#     [code block]
# ```
# Run the if statement from the example above, without the elif or else statement.
#
# Then, change the numbers or inequalities to see how the output changes.
#
# Print something after the if statement so you know it ran.

# %%
# Simple stand alone if statement

# %% [markdown]
# ### if-else construct
# If you want to test one conditional, but if it is `False`, always do something else, then the `if`-`else` construct is for you! Note that in the `else` there is no conditional statement as it is a catch-all and will always be executed if the initial conditional is `False`.
#
# ```python
# if condition:
#     [code block]
# else:
#     [default code block]
# ```
# Modify the code above to use an else statement.

# %%
# If-else Construct

# %% [markdown]
# ### if-elif construct
# If there are multiple conditions you would like to check, then you can combine the traditional if statment with elif (else if) statements that check other conditions. Note that as soon as a `True` condition is found it will not check any of the other conditional statments left within the if-elif structure. Once the `True` condition is found it will run the code block associated with that condition and then move on in the program after the if statment.
#
# ```python
# if condition1:
#     [code block one]
# elif condition2:
#     [code block two]
# elif condition3:
#     [code block three]
# ```
# Modify the example code we've been using to include an elif statement. Write output for if a is greater than b or if a is less than b. Modify it again to capture if a is equal to b.

# %%
# If-elif Construct

# %% [markdown]
# ### if-elif-else construct
# The full complement of an if statement can contain one `if`, any number of `elif`s, and an `else` statment. Again, once a `True` condition is found it will run the code block associated with that condition and then move on in the program after the if statment.
#
# ```python
# if condition1:
#     [code block one]
# elif condition2:
#     [code block two]
# elif condition3:
#     [code block three]
# else:
#     [default code block]
# ```
# Modify the example code to include an else statement to test if nothing is true.
#
# Then, add two more values `c` and `d`. Test if a is less than b and c is greater than d. If it's false, then use if-elif-else statements to print out how it's false.

# %%
# If-elif-elif-else Construct

# %% [markdown]
# Note that in these if and elif statements, you have the option to just write `if variable:`.
# * If the variable is a string, integer, or float that is not zero, then the statement will be read as being `True`. If the variable is zero, the statement will be read as being `False`.
# * If the variable is a list, dictionary, set, or tuple object that has any elements in it, the statement will be read as `True`. We call the object (list, dictionary, set, or tuple) a non-empty object. Conversely, if the object has no elements in it, it is an empty object and the statement will be read as `False`.
#
# **Zero or empty objects are `False`, all other values and non-empty objects are `True`.**
#
# We tested this above with the `bool()` function. Test them here with just `if variable:`

# %%
# Test some variables to see how they are evaluated.
