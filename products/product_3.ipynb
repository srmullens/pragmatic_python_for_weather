# %% [markdown]
# # Assignment #3
#
# This assignment can be completed by adding code to this notebook for each question.
#
# Either turn in a single notebook or a series of Python scripts.
#
# * If you turn in a single notebook, name it:
#     * `assignment_3_<username>.ipynb`.
#
# * If you turn in a series of Python scripts, name them:
#     * Question 1: `assignment_3_<username>_q1.py`
#     * Question 2: `assignment_3_<username>_q2.py`
#     * Question 3: `assignment_3_<username>_q3.py`
#
# with your `<username>` being your Github login name (e.g., mine is `srmullens`) to /share/share/assignments/. May need to use the Linux terminal and commands.
#
# Prior to turning in your notebook, please cleanup and comment your code for each problem. Be sure that your output is self-describing.
#
# This assignment is worth 50 points.

# %% [markdown]
# ## Question #1
# (10 points) Write Python code that will read in the pressures from a file called **hw3_pressures.dat** and
#
# a) Compute the average from a random sample of 100 values from your file. The file contains 500 values and you should choose a random set of 100 from the 500 to complete this problem.
#
# b) Print the average pressure and alert for High, Low, or Normal Pressure given:
#   - If the average of the pressures is greater than 1016 hPa, alert that pressure is high.
#   - If the average of the pressures is lower than 1004 hPa, alert that the pressure is low.
#   - Otherwise alert that the pressure is normal.
#
# Pressures in the file are in hPa.
#
# File is located in `/products/data/hw3_pressures.dat`.
#
# Input:
# * Pressures from the file.
#
# Output:
# * The average of the 100 randomnly chosen pressures
# * The appropriate alert based on the average of the pressures
#
# Notes:
# * Make sure documentation (e.g., comment block and comments throughout code) is present in your source code
# * Be sure to use the functionality from NumPy to help randomly select the pressure values.
# * Break the problem down and complete simpler tasks first and work toward putting it all together.
# * Make output informative so that anyone running your program understands what is being produced without seeing the assignment.
# * Have all of your code for this problem contained in one cell when you turn it in.

# %% [markdown]
# ## Question #2
# (20 points) Read in a dataset that contains a number of latitude/longitude pairs in each row. Write a definition using Python code to calculate the great circle distance between two latitude/longitude points using an array of values. Use the definition to calculate all of the distances and find the largest and smallest distances from the location pairs in the file. Output both locations and distance from the data provided. Output the largest and smallest distances from the data provided.
#
# The great circle distance can be calculated using the haversine formula:
#
# * $\phi$ is latitude. Difference between latitudes is $\Delta \phi = (\phi_2 - \phi_1) $
# * $\lambda$ is longitude. Difference between longitudes is $\Delta \lambda = (\lambda_2 - \lambda_1) $
# * R is earth’s radius. $R = 6,371km$
#
# Note that angles need to be in radians in the trig functions!
#
# $a =  sin^2(\frac{\Delta \phi}{2}) + cos \phi_1 * cos \phi_2 * sin^2(\frac{\Delta \lambda}{2})$
#
# $d = 2 * R * asin^2(\sqrt{a})$
#
#
# Notes:
# * There are Numpy functions to help you convert from degrees to radians.
# * Use of a definition might help in making more readable and reusable code.
# * $sin^2(x)$ is equivalent to saying $(sin(x))^2$.
# * Have all of your code for this problem contained in one cell when you turn it in.
#
# Input:
# * Latitude/Longitude points from `destination_locations.txt` (Available in `products/data/`.)
#
# Output:
# * Original Latitude/Longitude points and the distance in kilometers between them for each latitude/longitude pair.
# * Identify and print out the shortest and longest distances between points in the dataset.
#
# ```
# Example Calculation #1:
#
# 1237 km between (42.3,-101.3) and (39.35,-87.1).
#
#
# Example Calculation #2:
#
# 6331 km between (52.3,0.5) and (42.5,-88.1).
# ```

# %% [markdown]
# ## Question #3
# (20 points) Write Python code to determine the average, maximum, and minimum SOI for each year. Also determine the number of months that the standardized Southern Oscillation Index (SOI) indicate El Nino conditions (defined for this assignment as SOI <= -1.25) or La Nina conditions (defined for this assignment as SOI >= 1.25). Report the month, year, and SOI value along with the designation of El Nino or La Nina for each individual El Nino or La Nina month. Finally, determine the maximum and minimum value SOI over the entire period, reporting the month and year they occurred in. Print all of the above results to the screen.
#
# Input File: `soi_data.txt` (Available in `products/data`.)
#
# Output:
# * The average SOI value for each year.
# * The maximum SOI value for each year.
# * The minimum SOI value for each year.
# * Month, Year, and SOI values for El Nino and La Nina Months.
# * The total number of months spent in La Nina for the dataset.
# * The total number of months spent in El Nino for the dataset.
# * The overall maximum and minimum SOI value in the dataset and the month it occurred.
#
# **Background**
#
# The Southern Oscillation Index (SOI) is a measure of the difference between sea level pressure in Tahiti and Darwin, Australian, which gives a proxy for shifts in the Walker Circulation and thus the El Nino – Southern Oscillation (ENSO). There are many other ways to define ENSO periods and a good resource for background information can be found at: https://www.climate.gov/news-features/blogs/enso/why-are-there-so-many-enso-indexes-instead-just-one.
#
# Generally, an El Nino or La Nina event cannot be determined from any one month of an ENSO index. Instead, the average for a three-month period is often used. However, for simplicity in this assignment, we define an El Nino event when the SOI value is below -1.25 for any particular month and a La Nina event when the SOI value is above 1.25 for any particular month.
#
# Notes:
# * Break the problem down into smaller bite-size pieces. For example, first write your program to be able to read in the input file and separate out the year column from the SOI data columns. Then work to find the global max and min values. Then work on finding individual months that can be classified as El Nino, etc.
# * Make sure to regularly save your work.
# * Be sure to verify that your results are correct.
# * Have all of your code for this problem contained in one cell when you turn it in.
#
# Please make your program to produce output in a similar fashion as the test cases below.
#
# Example Output (but with fake data):
#
# ```
# Year  Max SOI  Avg. SOI  Min SOI
# 2024    1.34      0.45    -1.12
# 2025    0.98      0.03    -2.10
#
# .
#
# .
#
# .
#
# ----------
#
# El Nino: February 2030. SOI: -3.5
# La Nina: July 2031. SOI: 1.4
#
# .
#
# .
#
# .
#
# .
#
# ----------
#
# Max SOI of 2.2 occurred in October 2050
#
# Min SOI of -3.1 occurred in December 2024
#
# Number of La Nina Months: 25
#
# Number of El Nino Months: 33
# ```
