# %% [markdown]
# # Assignment #2
#
# This assignment can be completed by adding code to this notebook for each question.
#
# Turn in a completed notebook. Name the program `assignment_2_<username>.ipynb`. Download the file and upload it to Canvas.
#
# This assignment is worth 50 points.

# %% [markdown]
# ## Question #1
# Numerical weather prediction models are typically run at least four times a day at 00, 06, 12, and 18 UTC. If you are writing code to analyze some model output you might need to choose the appropriate model run time so your code doesn't fail whenever it runs. (10 points)
#
# Write Python code to choose an appropriate model run (00, 06, 12, 18 UTC) based on a given input hour.
# * Choose 00 UTC model run if the current time is between 0300 – 0859 UTC.
# * Choose 06 UTC model run if the current time is between 0900 – 1459 UTC.
# * Choose 12 UTC model run if the current time is between 1500 – 2059 UTC.
# * Choose 18 UTC model run otherwise.
#
# Input of times should come from standard input. Be sure to prompt the user appropriately.
#
# Output the choice of model runs (00, 06, 12, or 18 UTC) to standard output (print to screen).

# %%
time = 12

# %% [markdown]
# ## Question #2
# Write Python code to determine whether a given year is a leap year or not. Output both the year and whether or not it is a leap year. (10 points)
#
# *Leap Year Definition*
#
# > Add a leap day every four years when the year is divisible by 4, but not if the year is divisible by 100 unless it is also divisible by 400.
#
# Known leap year values:
# ```
# 1996 is a leap year
# 2000 is a leap year
# 1900 is not a leap year
# 1994 is not a leap year
# ```

# %% [markdown]
# ## Question #3
# Write one definition to convert a tuple containing four elements describing a location in degrees, minutes, seconds, and direction (e.g., N, S, E, W) into the location value in decimal degrees. Have it return the converted location value. Make the defenition work for both northern and southern hemispheric locations and east and west longitude designations (e.g., south and west are negative decimal degree values). Call the function `dms_decimal_degrees`. Since you are creating a definition, create an appropriate docstring. (10 points)
#
# Example Tuples:
# ```
# lat_loc = (29, 38, 58, 'N')
# lon_loc = (82, 20, 37, 'W')
# ```
# ```
# lat_loc = (33, 51, 26, 'S')
# lon_loc = (151, 12, 55, 'E')
# ```
#
# Test your definition with one location tuple of your choosing and print the result of the function.

# %%
# Write your definition here

# %%
# Test your definition here

# %% [markdown]
# ## Question #4
# Write a loop to convert the list of tuple locations using the definition you created for question #3. The output for each location should contain the input value in degrees, minutes, seconds, and the converted value in decimal degrees. (10 points)
#
# ```
# locations = [((50, 43, 58, 'N'),(1, 9, 31, 'W')),
#              ((22, 57, 7, 'S'),(43, 12, 38, 'W')),
#              ((33, 51, 54, 'S'),(151, 12, 36, 'E'),
#              ((35, 21, 46, 'N'),(138, 43, 51, 'E'))]
# ```

# %% [markdown]
# ## Question #5
#
# On August 2, 2021, the National Weather Service began issuing damage threat tags in severe thunderstorm warnings. These tags are "base", "considerable", and "destructive" labels similar to the tags used for tornado and flash flood warnings.
#
# A table of the criteria for severe thunderstorm warning tags is reproduced below. The damage tag is used if either the wind speed or hail diameter is greater than the value in each row. The table also shows when a Wireless Emergency Alert (WEA) should be issued. This table comes from: https://www.weather.gov/lot/SevereThunderstormWarningsUpdate
# | Damage Tag | Wind Speed | Hail diameter | WEA? |
# | :-: |  :-: |  :-: |  :-: |
# | Base | 58 mph | 1.00 inch | NO |
# | Considerable | 70 mph  | 1.75 inch | NO |
# | Destructive | 80 mph | 2.75 inch | YES |
#
# Given this table, write code that inputs the maximum expected wind speed and hail diameter. Print out 1) what values were input, 2) the appropriate damage tag, and 3) whether a WEA should be issued. Be sure the output explains what is happening so the user doesn't need to see the code itself. Use comments appropriately. (10 points)
